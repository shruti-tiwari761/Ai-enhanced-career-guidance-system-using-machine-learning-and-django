# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("Mathematics.csv")
df
# Out:
#               Full Name Age  Gender  Class              Stream :  \
# 0                Shubhi  15  Female  11 th  Science(Mathematics)
# 1    Priyanka Prajapati  18  Female  12 th  Science(Mathematics)
# 2        akanksha yadav  17  Female  12 th  Science(Mathematics)
# 3        Anamika kewat   17  Female  12 th  Science(Mathematics)
# 4      Heeru prajapati   17    Male  12 th  Science(Mathematics)
# ..                  ...  ..     ...    ...                   ...
# 193             Shahnaz  18  Female  12 th  Science(Mathematics)
# 194        Chaman rana   17    Male  11 th  Science(Mathematics)
# 195         Akaash rai   17    Male  12 th  Science(Mathematics)
# 196           Aman rai   18    Male  12 th  Science(Mathematics)
# 197        Ramesh singh  18    Male  12 th  Science(Mathematics)
#
#     How confident are you in your understanding of Mathematics?    \
# 0                                            Confident
# 1                                            Confident
# 2                                            Confident
# 3                                            Confident
# 4                                   Slightly Confident
# ..                                                 ...
# 193                                      Not Confident
# 194                                 Slightly Confident
# 195                                          Confident
# 196                                          Confident
# 197                                          Confident
#
#     How would you rate your performance in subjects related to Mathematics (e.g., Mathematics, Physics, Computer Science)?    \
# 0                                              Average
# 1                                            Excellent
# 2                                            Excellent
# 3                                            Excellent
# 4                                              Average
# ..                                                 ...
# 193                                            Average
# 194                                            Average
# 195                                               Good
# 196                                          Excellent
# 197                                            Average
#
#     Which area of Mathematics interests you the most?    \
# 0                    Calculus, Statistics, Probability
# 1    Algebra, Calculus, Statistics, Probability, Tr...
# 2                                             Calculus
# 3       Algebra, Statistics, Probability, Trigonometry
# 4                                         Trigonometry
# ..                                                 ...
# 193                             Calculus, Trigonometry
# 194  Algebra, Probability, Trigonometry, Discrete M...
# 195    Calculus, Statistics, Probability, Trigonometry
# 196  Algebra, Geometry, Calculus, Statistics, Trigo...
# 197  Algebra, Statistics, Trigonometry, Discrete Ma...
#
#     How interested are you in pursuing a career in fields that require strong mathematical skills (e.g., Engineering, Data Science, Finance, Research)?    \
# 0                                  Slightly Interested
# 1                                      Very Interested
# 2                                           Interested
# 3                          Neutral/Somewhat Interested
# 4                                  Slightly Interested
# ..                                                 ...
# 193                                    Very Interested
# 194                                Slightly Interested
# 195                                         Interested
# 196                                         Interested
# 197                                         Interested
#
#     Do you have any extracurricular interests related to Mathematics or related fields?    \
# 0     Competitions (e.g., Math Olympiad, Science Fair)
# 1    Coding or Programming, Data Science Projects, ...
# 2                     AI and Machine Learning Projects
# 3        Math Club, Engineering or Technical Workshops
# 4                                Coding or Programming
# ..                                                 ...
# 193  Competitions (e.g., Math Olympiad, Science Fai...
# 194   Competitions (e.g., Math Olympiad, Science Fair)
# 195  Math Club, Coding or Programming, Engineering ...
# 196  Coding or Programming, Data Science Projects, ...
# 197  Coding or Programming, Data Science Projects, ...
#
#     How important is a career that involves Mathematics for you?    \
# 0                                   Somewhat Important
# 1                                       Very Important
# 2                                       Very Important
# 3                                        Not Important
# 4                                       Very Important
# ..                                                 ...
# 193                                      Not Important
# 194                                     Very Important
# 195                                     Very Important
# 196                                     Very Important
# 197                                     Very Important
#
#      How do you rate your problem-solving skills in mathematical contexts?    \
# 0                                                 Good
# 1                                            Excellent
# 2                                            Excellent
# 3                                                 Good
# 4                                              Average
# ..                                                 ...
# 193                                      Below Average
# 194                                            Average
# 195                                            Average
# 196                                            Average
# 197                                               Good
#
#     Do you enjoy working on math-related projects or problems?    \
# 0                                            Sometimes
# 1                                                  Yes
# 2                                                  Yes
# 3                                                  Yes
# 4                                                   No
# ..                                                 ...
# 193                                          Sometimes
# 194                                                Yes
# 195                                                Yes
# 196                                                Yes
# 197                                                Yes
#
#     Do you prefer working in teams for solving math-related problems?    \
# 0                                                  Yes
# 1                                                  Yes
# 2                                           It depends
# 3                                                  Yes
# 4                                                   No
# ..                                                 ...
# 193                                         It depends
# 194                                                Yes
# 195                                                Yes
# 196                                                Yes
# 197                                                Yes
#
#     How comfortable are you with using technology or software (e.g., Java, Python, C, etc) for solving mathematical problems?
# 0                                 Slightly Comfortable
# 1                         Neutral/Somewhat Comfortable
# 2                                          Comfortable
# 3                         Neutral/Somewhat Comfortable
# 4                                 Slightly Comfortable
# ..                                                 ...
# 193                       Neutral/Somewhat Comfortable
# 194                       Neutral/Somewhat Comfortable
# 195                                        Comfortable
# 196                                        Comfortable
# 197                                        Comfortable
#
# [198 rows x 15 columns]

# %%
df.shape
# Out:
# (198, 15)

# %%
df.columns
# Out:
# Index(['Full Name', 'Age', 'Gender', 'Class', 'Stream :',
#        'How confident are you in your understanding of Mathematics?  ',
#        'How would you rate your performance in subjects related to Mathematics (e.g., Mathematics, Physics, Computer Science)?  ',
#        'Which area of Mathematics interests you the most?  ',
#        'How interested are you in pursuing a career in fields that require strong mathematical skills (e.g., Engineering, Data Science, Finance, Research)?  ',
#        'Do you have any extracurricular interests related to Mathematics or related fields?  ',
#        'How important is a career that involves Mathematics for you?  ',
#        ' How do you rate your problem-solving skills in mathematical contexts?  ',
#        'Do you enjoy working on math-related projects or problems?  ',
#        'Do you prefer working in teams for solving math-related problems?  ',
#        'How comfortable are you with using technology or software (e.g., Java, Python, C, etc) for solving mathematical problems?  '],
#       dtype='object')

# %%
columns_to_drop = ['Full Name', 'Age', 'Gender', 'Class', 'Stream :','Which area of Mathematics interests you the most?  ','Do you have any extracurricular interests related to Mathematics or related fields?  ']  # Adjust these names if they are different in the dataset
df = df.drop(columns=[col for col in columns_to_drop if col in df.columns])  # Drop only existing columns
df
# Out:
#     How confident are you in your understanding of Mathematics?    \
# 0                                            Confident
# 1                                            Confident
# 2                                            Confident
# 3                                            Confident
# 4                                   Slightly Confident
# ..                                                 ...
# 193                                      Not Confident
# 194                                 Slightly Confident
# 195                                          Confident
# 196                                          Confident
# 197                                          Confident
#
#     How would you rate your performance in subjects related to Mathematics (e.g., Mathematics, Physics, Computer Science)?    \
# 0                                              Average
# 1                                            Excellent
# 2                                            Excellent
# 3                                            Excellent
# 4                                              Average
# ..                                                 ...
# 193                                            Average
# 194                                            Average
# 195                                               Good
# 196                                          Excellent
# 197                                            Average
#
#     How interested are you in pursuing a career in fields that require strong mathematical skills (e.g., Engineering, Data Science, Finance, Research)?    \
# 0                                  Slightly Interested
# 1                                      Very Interested
# 2                                           Interested
# 3                          Neutral/Somewhat Interested
# 4                                  Slightly Interested
# ..                                                 ...
# 193                                    Very Interested
# 194                                Slightly Interested
# 195                                         Interested
# 196                                         Interested
# 197                                         Interested
#
#     How important is a career that involves Mathematics for you?    \
# 0                                   Somewhat Important
# 1                                       Very Important
# 2                                       Very Important
# 3                                        Not Important
# 4                                       Very Important
# ..                                                 ...
# 193                                      Not Important
# 194                                     Very Important
# 195                                     Very Important
# 196                                     Very Important
# 197                                     Very Important
#
#      How do you rate your problem-solving skills in mathematical contexts?    \
# 0                                                 Good
# 1                                            Excellent
# 2                                            Excellent
# 3                                                 Good
# 4                                              Average
# ..                                                 ...
# 193                                      Below Average
# 194                                            Average
# 195                                            Average
# 196                                            Average
# 197                                               Good
#
#     Do you enjoy working on math-related projects or problems?    \
# 0                                            Sometimes
# 1                                                  Yes
# 2                                                  Yes
# 3                                                  Yes
# 4                                                   No
# ..                                                 ...
# 193                                          Sometimes
# 194                                                Yes
# 195                                                Yes
# 196                                                Yes
# 197                                                Yes
#
#     Do you prefer working in teams for solving math-related problems?    \
# 0                                                  Yes
# 1                                                  Yes
# 2                                           It depends
# 3                                                  Yes
# 4                                                   No
# ..                                                 ...
# 193                                         It depends
# 194                                                Yes
# 195                                                Yes
# 196                                                Yes
# 197                                                Yes
#
#     How comfortable are you with using technology or software (e.g., Java, Python, C, etc) for solving mathematical problems?
# 0                                 Slightly Comfortable
# 1                         Neutral/Somewhat Comfortable
# 2                                          Comfortable
# 3                         Neutral/Somewhat Comfortable
# 4                                 Slightly Comfortable
# ..                                                 ...
# 193                       Neutral/Somewhat Comfortable
# 194                       Neutral/Somewhat Comfortable
# 195                                        Comfortable
# 196                                        Comfortable
# 197                                        Comfortable
#
# [198 rows x 8 columns]

# %%
# Loop through each column and check for object dtype
for column in df.columns:
    if df[column].dtype == 'object':  # Check if column type is object
        unique_values = sorted(df[column].unique())
        print(f"Column: '{column}'")
        print(f"Number of unique values: {len(unique_values)}")
        print(f"Unique values: {unique_values}")
        print("-" * 50)
# Out:
# Column: 'How confident are you in your understanding of Mathematics?  '
# Number of unique values: 4
# Unique values: ['Confident', 'Neutral/Somewhat Confident', 'Not Confident', 'Slightly Confident']
# --------------------------------------------------
# Column: 'How would you rate your performance in subjects related to Mathematics (e.g., Mathematics, Physics, Computer Science)?  '
# Number of unique values: 5
# Unique values: ['Average', 'Below Average', 'Excellent', 'Good', 'Poor']
# --------------------------------------------------
# Column: 'How interested are you in pursuing a career in fields that require strong mathematical skills (e.g., Engineering, Data Science, Finance, Research)?  '
# Number of unique values: 5
# Unique values: ['Interested', 'Neutral/Somewhat Interested', 'Not Interested', 'Slightly Interested', 'Very Interested']
# --------------------------------------------------
# Column: 'How important is a career that involves Mathematics for you?  '
# Number of unique values: 3
# Unique values: ['Not Important', 'Somewhat Important', 'Very Important']
# --------------------------------------------------
# Column: ' How do you rate your problem-solving skills in mathematical contexts?  '
# Number of unique values: 5
# Unique values: ['Average', 'Below Average', 'Excellent', 'Good', 'Not Good']
# --------------------------------------------------
# Column: 'Do you enjoy working on math-related projects or problems?  '
# Number of unique values: 3
# Unique values: ['No', 'Sometimes', 'Yes']
# --------------------------------------------------
# Column: 'Do you prefer working in teams for solving math-related problems?  '
# Number of unique values: 3
# Unique values: ['It depends', 'No', 'Yes']
# --------------------------------------------------
# Column: 'How comfortable are you with using technology or software (e.g., Java, Python, C, etc) for solving mathematical problems?  '
# Number of unique values: 4
# Unique values: ['Comfortable', 'Neutral/Somewhat Comfortable', 'Not Comfortable', 'Slightly Comfortable']
# --------------------------------------------------

# %%
def classify_student(row):
    # Assign weights to key responses for classification
    scores = {
        "Not Confident": 1, "Slightly Confident": 2, "Neutral/Somewhat Confident": 3, "Confident": 4,
        "Poor": 1, "Below Average": 2, "Average": 3, "Good": 4, "Excellent": 5,
        "Not Interested": 1, "Slightly Interested": 2, "Neutral/Somewhat Interested": 3, "Interested": 4, "Very Interested": 5,
        "Not Important": 1, "Somewhat Important": 3, "Very Important": 5,
        "Not Good": 1, "Below Average": 2, "Average": 3, "Good": 4, "Excellent": 5,
        "No": 1, "Sometimes": 2, "Yes": 3,
        "It depends": 2, "Not Comfortable": 1, "Slightly Comfortable": 2, "Neutral/Somewhat Comfortable": 3, "Comfortable": 4, "Very Comfortable": 5
    }
    
    # Map scores for each column based on the student's responses
    confidence_score = scores.get(row["How confident are you in your understanding of Mathematics?  "], 0)
    performance_score = scores.get(row["How would you rate your performance in subjects related to Mathematics (e.g., Mathematics, Physics, Computer Science)?  "], 0)
    career_interest_score = scores.get(row["How interested are you in pursuing a career in fields that require strong mathematical skills (e.g., Engineering, Data Science, Finance, Research)?  "], 0)
    importance_score = scores.get(row["How important is a career that involves Mathematics for you?  "], 0)
    problem_solving_score = scores.get(row[' How do you rate your problem-solving skills in mathematical contexts?  '], 0)
    project_enjoyment_score = scores.get(row["Do you enjoy working on math-related projects or problems?  "], 0)
    teamwork_score = scores.get(row["Do you prefer working in teams for solving math-related problems?  "], 0)
    technology_comfort_score = scores.get(row["How comfortable are you with using technology or software (e.g., Java, Python, C, etc) for solving mathematical problems?  "], 0)

    # Compute total score
    total_score = (
        confidence_score
        + performance_score
        + career_interest_score
        + importance_score
        + problem_solving_score
        + project_enjoyment_score
        + teamwork_score
        + technology_comfort_score
    )
    
    # Classification thresholds and biology degree suggestions
    if total_score >= 30:
        recommendation = "Highly Recommended"
        degree = "Pure Mathematics, Applied Mathematics, Data Science, Machine Learning, Actuarial Science, or Mathematical Modelling"
    elif total_score >= 20:
        recommendation = "Neutral"
        degree = "Statistics, Mathematical Biology, Econometrics, or Operations Research"
    else:
        recommendation = "Not Recommended"
        degree = "Consider exploring fields outside of mathematics, such as Humanities or Business"

    return recommendation, degree

# Apply the function to classify students and suggest degrees
df[["Career Guidance Recommendation", "Suggested Degree"]] = df.apply(
    lambda row: pd.Series(classify_student(row)), axis=1
)

# %%
df
# Out:
#     How confident are you in your understanding of Mathematics?    \
# 0                                            Confident
# 1                                            Confident
# 2                                            Confident
# 3                                            Confident
# 4                                   Slightly Confident
# ..                                                 ...
# 193                                      Not Confident
# 194                                 Slightly Confident
# 195                                          Confident
# 196                                          Confident
# 197                                          Confident
#
#     How would you rate your performance in subjects related to Mathematics (e.g., Mathematics, Physics, Computer Science)?    \
# 0                                              Average
# 1                                            Excellent
# 2                                            Excellent
# 3                                            Excellent
# 4                                              Average
# ..                                                 ...
# 193                                            Average
# 194                                            Average
# 195                                               Good
# 196                                          Excellent
# 197                                            Average
#
#     How interested are you in pursuing a career in fields that require strong mathematical skills (e.g., Engineering, Data Science, Finance, Research)?    \
# 0                                  Slightly Interested
# 1                                      Very Interested
# 2                                           Interested
# 3                          Neutral/Somewhat Interested
# 4                                  Slightly Interested
# ..                                                 ...
# 193                                    Very Interested
# 194                                Slightly Interested
# 195                                         Interested
# 196                                         Interested
# 197                                         Interested
#
#     How important is a career that involves Mathematics for you?    \
# 0                                   Somewhat Important
# 1                                       Very Important
# 2                                       Very Important
# 3                                        Not Important
# 4                                       Very Important
# ..                                                 ...
# 193                                      Not Important
# 194                                     Very Important
# 195                                     Very Important
# 196                                     Very Important
# 197                                     Very Important
#
#      How do you rate your problem-solving skills in mathematical contexts?    \
# 0                                                 Good
# 1                                            Excellent
# 2                                            Excellent
# 3                                                 Good
# 4                                              Average
# ..                                                 ...
# 193                                      Below Average
# 194                                            Average
# 195                                            Average
# 196                                            Average
# 197                                               Good
#
#     Do you enjoy working on math-related projects or problems?    \
# 0                                            Sometimes
# 1                                                  Yes
# 2                                                  Yes
# 3                                                  Yes
# 4                                                   No
# ..                                                 ...
# 193                                          Sometimes
# 194                                                Yes
# 195                                                Yes
# 196                                                Yes
# 197                                                Yes
#
#     Do you prefer working in teams for solving math-related problems?    \
# 0                                                  Yes
# 1                                                  Yes
# 2                                           It depends
# 3                                                  Yes
# 4                                                   No
# ..                                                 ...
# 193                                         It depends
# 194                                                Yes
# 195                                                Yes
# 196                                                Yes
# 197                                                Yes
#
#     How comfortable are you with using technology or software (e.g., Java, Python, C, etc) for solving mathematical problems?    \
# 0                                 Slightly Comfortable
# 1                         Neutral/Somewhat Comfortable
# 2                                          Comfortable
# 3                         Neutral/Somewhat Comfortable
# 4                                 Slightly Comfortable
# ..                                                 ...
# 193                       Neutral/Somewhat Comfortable
# 194                       Neutral/Somewhat Comfortable
# 195                                        Comfortable
# 196                                        Comfortable
# 197                                        Comfortable
#
#     Career Guidance Recommendation  \
# 0                          Neutral
# 1               Highly Recommended
# 2               Highly Recommended
# 3                          Neutral
# 4                  Not Recommended
# ..                             ...
# 193                Not Recommended
# 194                        Neutral
# 195             Highly Recommended
# 196             Highly Recommended
# 197             Highly Recommended
#
#                                       Suggested Degree
# 0    Statistics, Mathematical Biology, Econometrics...
# 1    Pure Mathematics, Applied Mathematics, Data Sc...
# 2    Pure Mathematics, Applied Mathematics, Data Sc...
# 3    Statistics, Mathematical Biology, Econometrics...
# 4    Consider exploring fields outside of mathemati...
# ..                                                 ...
# 193  Consider exploring fields outside of mathemati...
# 194  Statistics, Mathematical Biology, Econometrics...
# 195  Pure Mathematics, Applied Mathematics, Data Sc...
# 196  Pure Mathematics, Applied Mathematics, Data Sc...
# 197  Pure Mathematics, Applied Mathematics, Data Sc...
#
# [198 rows x 10 columns]

# %%
duplicates=df[df.duplicated()]
duplicates
# Out:
#     How confident are you in your understanding of Mathematics?    \
# 30                                           Confident
# 36                                  Slightly Confident
# 45                                  Slightly Confident
# 51                                           Confident
# 69                                           Confident
# 70                                           Confident
# 73                                           Confident
# 79                                           Confident
# 80                                           Confident
# 87                          Neutral/Somewhat Confident
# 88                                           Confident
# 89                                           Confident
# 97                                           Confident
# 98                                           Confident
# 99                                           Confident
# 105                                          Confident
# 107                         Neutral/Somewhat Confident
# 111                         Neutral/Somewhat Confident
# 112                                          Confident
# 116                                          Confident
# 117                                          Confident
# 120                         Neutral/Somewhat Confident
# 127                         Neutral/Somewhat Confident
# 195                                          Confident
#
#     How would you rate your performance in subjects related to Mathematics (e.g., Mathematics, Physics, Computer Science)?    \
# 30                                                Good
# 36                                             Average
# 45                                             Average
# 51                                           Excellent
# 69                                           Excellent
# 70                                           Excellent
# 73                                           Excellent
# 79                                           Excellent
# 80                                           Excellent
# 87                                                Good
# 88                                           Excellent
# 89                                           Excellent
# 97                                           Excellent
# 98                                           Excellent
# 99                                                Good
# 105                                          Excellent
# 107                                               Good
# 111                                               Good
# 112                                          Excellent
# 116                                               Good
# 117                                               Good
# 120                                               Good
# 127                                               Good
# 195                                               Good
#
#     How interested are you in pursuing a career in fields that require strong mathematical skills (e.g., Engineering, Data Science, Finance, Research)?    \
# 30                                          Interested
# 36                                 Slightly Interested
# 45                                 Slightly Interested
# 51                                          Interested
# 69                                     Very Interested
# 70                                     Very Interested
# 73                                          Interested
# 79                                     Very Interested
# 80                                     Very Interested
# 87                                          Interested
# 88                                     Very Interested
# 89                                     Very Interested
# 97                                     Very Interested
# 98                                     Very Interested
# 99                                          Interested
# 105                                    Very Interested
# 107                                    Very Interested
# 111                                         Interested
# 112                                         Interested
# 116                                         Interested
# 117                                         Interested
# 120                                    Very Interested
# 127                                         Interested
# 195                                         Interested
#
#     How important is a career that involves Mathematics for you?    \
# 30                                      Very Important
# 36                                  Somewhat Important
# 45                                      Very Important
# 51                                      Very Important
# 69                                      Very Important
# 70                                      Very Important
# 73                                      Very Important
# 79                                      Very Important
# 80                                      Very Important
# 87                                      Very Important
# 88                                      Very Important
# 89                                      Very Important
# 97                                      Very Important
# 98                                      Very Important
# 99                                      Very Important
# 105                                     Very Important
# 107                                     Very Important
# 111                                     Very Important
# 112                                     Very Important
# 116                                     Very Important
# 117                                     Very Important
# 120                                     Very Important
# 127                                     Very Important
# 195                                     Very Important
#
#      How do you rate your problem-solving skills in mathematical contexts?    \
# 30                                                Good
# 36                                             Average
# 45                                             Average
# 51                                                Good
# 69                                           Excellent
# 70                                           Excellent
# 73                                           Excellent
# 79                                           Excellent
# 80                                           Excellent
# 87                                             Average
# 88                                           Excellent
# 89                                                Good
# 97                                           Excellent
# 98                                           Excellent
# 99                                                Good
# 105                                          Excellent
# 107                                               Good
# 111                                               Good
# 112                                          Excellent
# 116                                               Good
# 117                                               Good
# 120                                               Good
# 127                                          Excellent
# 195                                            Average
#
#     Do you enjoy working on math-related projects or problems?    \
# 30                                                 Yes
# 36                                           Sometimes
# 45                                                 Yes
# 51                                                 Yes
# 69                                                 Yes
# 70                                                 Yes
# 73                                                 Yes
# 79                                           Sometimes
# 80                                                 Yes
# 87                                           Sometimes
# 88                                                 Yes
# 89                                                 Yes
# 97                                                 Yes
# 98                                           Sometimes
# 99                                                 Yes
# 105                                                Yes
# 107                                                Yes
# 111                                          Sometimes
# 112                                                Yes
# 116                                                Yes
# 117                                                Yes
# 120                                                Yes
# 127                                          Sometimes
# 195                                                Yes
#
#     Do you prefer working in teams for solving math-related problems?    \
# 30                                                 Yes
# 36                                          It depends
# 45                                                 Yes
# 51                                                 Yes
# 69                                                 Yes
# 70                                                 Yes
# 73                                          It depends
# 79                                                 Yes
# 80                                                 Yes
# 87                                                 Yes
# 88                                                 Yes
# 89                                                 Yes
# 97                                                 Yes
# 98                                                 Yes
# 99                                                 Yes
# 105                                                Yes
# 107                                                Yes
# 111                                                Yes
# 112                                                Yes
# 116                                                Yes
# 117                                                Yes
# 120                                                Yes
# 127                                                Yes
# 195                                                Yes
#
#     How comfortable are you with using technology or software (e.g., Java, Python, C, etc) for solving mathematical problems?    \
# 30                                         Comfortable
# 36                                Slightly Comfortable
# 45                                Slightly Comfortable
# 51                                         Comfortable
# 69                                         Comfortable
# 70                                         Comfortable
# 73                                         Comfortable
# 79                                         Comfortable
# 80                                         Comfortable
# 87                        Neutral/Somewhat Comfortable
# 88                                         Comfortable
# 89                                         Comfortable
# 97                                         Comfortable
# 98                                         Comfortable
# 99                                         Comfortable
# 105                                        Comfortable
# 107                                        Comfortable
# 111                                        Comfortable
# 112                                        Comfortable
# 116                                        Comfortable
# 117                                        Comfortable
# 120                                        Comfortable
# 127                                        Comfortable
# 195                                        Comfortable
#
#     Career Guidance Recommendation  \
# 30              Highly Recommended
# 36                 Not Recommended
# 45                         Neutral
# 51              Highly Recommended
# 69              Highly Recommended
# 70              Highly Recommended
# 73              Highly Recommended
# 79              Highly Recommended
# 80              Highly Recommended
# 87                         Neutral
# 88              Highly Recommended
# 89              Highly Recommended
# 97              Highly Recommended
# 98              Highly Recommended
# 99              Highly Recommended
# 105             Highly Recommended
# 107             Highly Recommended
# 111                        Neutral
# 112             Highly Recommended
# 116             Highly Recommended
# 117             Highly Recommended
# 120             Highly Recommended
# 127             Highly Recommended
# 195             Highly Recommended
#
#                                       Suggested Degree
# 30   Pure Mathematics, Applied Mathematics, Data Sc...
# 36   Consider exploring fields outside of mathemati...
# 45   Statistics, Mathematical Biology, Econometrics...
# 51   Pure Mathematics, Applied Mathematics, Data Sc...
# 69   Pure Mathematics, Applied Mathematics, Data Sc...
# 70   Pure Mathematics, Applied Mathematics, Data Sc...
# 73   Pure Mathematics, Applied Mathematics, Data Sc...
# 79   Pure Mathematics, Applied Mathematics, Data Sc...
# 80   Pure Mathematics, Applied Mathematics, Data Sc...
# 87   Statistics, Mathematical Biology, Econometrics...
# 88   Pure Mathematics, Applied Mathematics, Data Sc...
# 89   Pure Mathematics, Applied Mathematics, Data Sc...
# 97   Pure Mathematics, Applied Mathematics, Data Sc...
# 98   Pure Mathematics, Applied Mathematics, Data Sc...
# 99   Pure Mathematics, Applied Mathematics, Data Sc...
# 105  Pure Mathematics, Applied Mathematics, Data Sc...
# 107  Pure Mathematics, Applied Mathematics, Data Sc...
# 111  Statistics, Mathematical Biology, Econometrics...
# 112  Pure Mathematics, Applied Mathematics, Data Sc...
# 116  Pure Mathematics, Applied Mathematics, Data Sc...
# 117  Pure Mathematics, Applied Mathematics, Data Sc...
# 120  Pure Mathematics, Applied Mathematics, Data Sc...
# 127  Pure Mathematics, Applied Mathematics, Data Sc...
# 195  Pure Mathematics, Applied Mathematics, Data Sc...

# %%
duplicates.shape
# Out:
# (24, 10)

# %%
df_cleaned = df.drop_duplicates()
df_cleaned
# Out:
#     How confident are you in your understanding of Mathematics?    \
# 0                                            Confident
# 1                                            Confident
# 2                                            Confident
# 3                                            Confident
# 4                                   Slightly Confident
# ..                                                 ...
# 192                                 Slightly Confident
# 193                                      Not Confident
# 194                                 Slightly Confident
# 196                                          Confident
# 197                                          Confident
#
#     How would you rate your performance in subjects related to Mathematics (e.g., Mathematics, Physics, Computer Science)?    \
# 0                                              Average
# 1                                            Excellent
# 2                                            Excellent
# 3                                            Excellent
# 4                                              Average
# ..                                                 ...
# 192                                               Good
# 193                                            Average
# 194                                            Average
# 196                                          Excellent
# 197                                            Average
#
#     How interested are you in pursuing a career in fields that require strong mathematical skills (e.g., Engineering, Data Science, Finance, Research)?    \
# 0                                  Slightly Interested
# 1                                      Very Interested
# 2                                           Interested
# 3                          Neutral/Somewhat Interested
# 4                                  Slightly Interested
# ..                                                 ...
# 192                                    Very Interested
# 193                                    Very Interested
# 194                                Slightly Interested
# 196                                         Interested
# 197                                         Interested
#
#     How important is a career that involves Mathematics for you?    \
# 0                                   Somewhat Important
# 1                                       Very Important
# 2                                       Very Important
# 3                                        Not Important
# 4                                       Very Important
# ..                                                 ...
# 192                                     Very Important
# 193                                      Not Important
# 194                                     Very Important
# 196                                     Very Important
# 197                                     Very Important
#
#      How do you rate your problem-solving skills in mathematical contexts?    \
# 0                                                 Good
# 1                                            Excellent
# 2                                            Excellent
# 3                                                 Good
# 4                                              Average
# ..                                                 ...
# 192                                           Not Good
# 193                                      Below Average
# 194                                            Average
# 196                                            Average
# 197                                               Good
#
#     Do you enjoy working on math-related projects or problems?    \
# 0                                            Sometimes
# 1                                                  Yes
# 2                                                  Yes
# 3                                                  Yes
# 4                                                   No
# ..                                                 ...
# 192                                          Sometimes
# 193                                          Sometimes
# 194                                                Yes
# 196                                                Yes
# 197                                                Yes
#
#     Do you prefer working in teams for solving math-related problems?    \
# 0                                                  Yes
# 1                                                  Yes
# 2                                           It depends
# 3                                                  Yes
# 4                                                   No
# ..                                                 ...
# 192                                                 No
# 193                                         It depends
# 194                                                Yes
# 196                                                Yes
# 197                                                Yes
#
#     How comfortable are you with using technology or software (e.g., Java, Python, C, etc) for solving mathematical problems?    \
# 0                                 Slightly Comfortable
# 1                         Neutral/Somewhat Comfortable
# 2                                          Comfortable
# 3                         Neutral/Somewhat Comfortable
# 4                                 Slightly Comfortable
# ..                                                 ...
# 192                               Slightly Comfortable
# 193                       Neutral/Somewhat Comfortable
# 194                       Neutral/Somewhat Comfortable
# 196                                        Comfortable
# 197                                        Comfortable
#
#     Career Guidance Recommendation  \
# 0                          Neutral
# 1               Highly Recommended
# 2               Highly Recommended
# 3                          Neutral
# 4                  Not Recommended
# ..                             ...
# 192                        Neutral
# 193                Not Recommended
# 194                        Neutral
# 196             Highly Recommended
# 197             Highly Recommended
#
#                                       Suggested Degree
# 0    Statistics, Mathematical Biology, Econometrics...
# 1    Pure Mathematics, Applied Mathematics, Data Sc...
# 2    Pure Mathematics, Applied Mathematics, Data Sc...
# 3    Statistics, Mathematical Biology, Econometrics...
# 4    Consider exploring fields outside of mathemati...
# ..                                                 ...
# 192  Statistics, Mathematical Biology, Econometrics...
# 193  Consider exploring fields outside of mathemati...
# 194  Statistics, Mathematical Biology, Econometrics...
# 196  Pure Mathematics, Applied Mathematics, Data Sc...
# 197  Pure Mathematics, Applied Mathematics, Data Sc...
#
# [174 rows x 10 columns]

# %%
df_cleaned.shape
# Out:
# (174, 10)

# %%
df_cleaned.isnull().sum()
# Out:
# How confident are you in your understanding of Mathematics?                                                                                              0
# How would you rate your performance in subjects related to Mathematics (e.g., Mathematics, Physics, Computer Science)?                                   0
# How interested are you in pursuing a career in fields that require strong mathematical skills (e.g., Engineering, Data Science, Finance, Research)?      0
# How important is a career that involves Mathematics for you?                                                                                             0
#  How do you rate your problem-solving skills in mathematical contexts?                                                                                   0
# Do you enjoy working on math-related projects or problems?                                                                                               0
# Do you prefer working in teams for solving math-related problems?                                                                                        0
# How comfortable are you with using technology or software (e.g., Java, Python, C, etc) for solving mathematical problems?                                0
# Career Guidance Recommendation                                                                                                                           0
# Suggested Degree                                                                                                                                         0
# dtype: int64

# %%
duplicates=df_cleaned[df_cleaned.duplicated()]
duplicates
# Out:
# Empty DataFrame
# Columns: [How confident are you in your understanding of Mathematics?  , How would you rate your performance in subjects related to Mathematics (e.g., Mathematics, Physics, Computer Science)?  , How interested are you in pursuing a career in fields that require strong mathematical skills (e.g., Engineering, Data Science, Finance, Research)?  , How important is a career that involves Mathematics for you?  ,  How do you rate your problem-solving skills in mathematical contexts?  , Do you enjoy working on math-related projects or problems?  , Do you prefer working in teams for solving math-related problems?  , How comfortable are you with using technology or software (e.g., Java, Python, C, etc) for solving mathematical problems?  , Career Guidance Recommendation, Suggested Degree]
# Index: []

# %%
columns_to_drop = ['Career Guidance Recommendation']  # Adjust these names if they are different in the dataset
df_cleaned= df_cleaned.drop(columns=[col for col in columns_to_drop if col in df_cleaned.columns])  # Drop only existing columns
df_cleaned
# Out:
#     How confident are you in your understanding of Mathematics?    \
# 0                                            Confident
# 1                                            Confident
# 2                                            Confident
# 3                                            Confident
# 4                                   Slightly Confident
# ..                                                 ...
# 192                                 Slightly Confident
# 193                                      Not Confident
# 194                                 Slightly Confident
# 196                                          Confident
# 197                                          Confident
#
#     How would you rate your performance in subjects related to Mathematics (e.g., Mathematics, Physics, Computer Science)?    \
# 0                                              Average
# 1                                            Excellent
# 2                                            Excellent
# 3                                            Excellent
# 4                                              Average
# ..                                                 ...
# 192                                               Good
# 193                                            Average
# 194                                            Average
# 196                                          Excellent
# 197                                            Average
#
#     How interested are you in pursuing a career in fields that require strong mathematical skills (e.g., Engineering, Data Science, Finance, Research)?    \
# 0                                  Slightly Interested
# 1                                      Very Interested
# 2                                           Interested
# 3                          Neutral/Somewhat Interested
# 4                                  Slightly Interested
# ..                                                 ...
# 192                                    Very Interested
# 193                                    Very Interested
# 194                                Slightly Interested
# 196                                         Interested
# 197                                         Interested
#
#     How important is a career that involves Mathematics for you?    \
# 0                                   Somewhat Important
# 1                                       Very Important
# 2                                       Very Important
# 3                                        Not Important
# 4                                       Very Important
# ..                                                 ...
# 192                                     Very Important
# 193                                      Not Important
# 194                                     Very Important
# 196                                     Very Important
# 197                                     Very Important
#
#      How do you rate your problem-solving skills in mathematical contexts?    \
# 0                                                 Good
# 1                                            Excellent
# 2                                            Excellent
# 3                                                 Good
# 4                                              Average
# ..                                                 ...
# 192                                           Not Good
# 193                                      Below Average
# 194                                            Average
# 196                                            Average
# 197                                               Good
#
#     Do you enjoy working on math-related projects or problems?    \
# 0                                            Sometimes
# 1                                                  Yes
# 2                                                  Yes
# 3                                                  Yes
# 4                                                   No
# ..                                                 ...
# 192                                          Sometimes
# 193                                          Sometimes
# 194                                                Yes
# 196                                                Yes
# 197                                                Yes
#
#     Do you prefer working in teams for solving math-related problems?    \
# 0                                                  Yes
# 1                                                  Yes
# 2                                           It depends
# 3                                                  Yes
# 4                                                   No
# ..                                                 ...
# 192                                                 No
# 193                                         It depends
# 194                                                Yes
# 196                                                Yes
# 197                                                Yes
#
#     How comfortable are you with using technology or software (e.g., Java, Python, C, etc) for solving mathematical problems?    \
# 0                                 Slightly Comfortable
# 1                         Neutral/Somewhat Comfortable
# 2                                          Comfortable
# 3                         Neutral/Somewhat Comfortable
# 4                                 Slightly Comfortable
# ..                                                 ...
# 192                               Slightly Comfortable
# 193                       Neutral/Somewhat Comfortable
# 194                       Neutral/Somewhat Comfortable
# 196                                        Comfortable
# 197                                        Comfortable
#
#                                       Suggested Degree
# 0    Statistics, Mathematical Biology, Econometrics...
# 1    Pure Mathematics, Applied Mathematics, Data Sc...
# 2    Pure Mathematics, Applied Mathematics, Data Sc...
# 3    Statistics, Mathematical Biology, Econometrics...
# 4    Consider exploring fields outside of mathemati...
# ..                                                 ...
# 192  Statistics, Mathematical Biology, Econometrics...
# 193  Consider exploring fields outside of mathemati...
# 194  Statistics, Mathematical Biology, Econometrics...
# 196  Pure Mathematics, Applied Mathematics, Data Sc...
# 197  Pure Mathematics, Applied Mathematics, Data Sc...
#
# [174 rows x 9 columns]

# %%
df_cleaned.to_csv("Mathematics1_cleaned.csv")

# %%
# Loop through each column and check for object dtype
for column in df_cleaned.columns:
    if df_cleaned[column].dtype == 'object':  # Check if column type is object
        unique_values = sorted(df_cleaned[column].unique())
        print(f"Column: '{column}'")
        print(f"Number of unique values: {len(unique_values)}")
        print(f"Unique values: {unique_values}")
        print("-" * 50)
# Out:
# Column: 'How confident are you in your understanding of Mathematics?  '
# Number of unique values: 4
# Unique values: ['Confident', 'Neutral/Somewhat Confident', 'Not Confident', 'Slightly Confident']
# --------------------------------------------------
# Column: 'How would you rate your performance in subjects related to Mathematics (e.g., Mathematics, Physics, Computer Science)?  '
# Number of unique values: 5
# Unique values: ['Average', 'Below Average', 'Excellent', 'Good', 'Poor']
# --------------------------------------------------
# Column: 'How interested are you in pursuing a career in fields that require strong mathematical skills (e.g., Engineering, Data Science, Finance, Research)?  '
# Number of unique values: 5
# Unique values: ['Interested', 'Neutral/Somewhat Interested', 'Not Interested', 'Slightly Interested', 'Very Interested']
# --------------------------------------------------
# Column: 'How important is a career that involves Mathematics for you?  '
# Number of unique values: 3
# Unique values: ['Not Important', 'Somewhat Important', 'Very Important']
# --------------------------------------------------
# Column: ' How do you rate your problem-solving skills in mathematical contexts?  '
# Number of unique values: 5
# Unique values: ['Average', 'Below Average', 'Excellent', 'Good', 'Not Good']
# --------------------------------------------------
# Column: 'Do you enjoy working on math-related projects or problems?  '
# Number of unique values: 3
# Unique values: ['No', 'Sometimes', 'Yes']
# --------------------------------------------------
# Column: 'Do you prefer working in teams for solving math-related problems?  '
# Number of unique values: 3
# Unique values: ['It depends', 'No', 'Yes']
# --------------------------------------------------
# Column: 'How comfortable are you with using technology or software (e.g., Java, Python, C, etc) for solving mathematical problems?  '
# Number of unique values: 4
# Unique values: ['Comfortable', 'Neutral/Somewhat Comfortable', 'Not Comfortable', 'Slightly Comfortable']
# --------------------------------------------------
# Column: 'Suggested Degree'
# Number of unique values: 3
# Unique values: ['Consider exploring fields outside of mathematics, such as Humanities or Business', 'Pure Mathematics, Applied Mathematics, Data Science, Machine Learning, Actuarial Science, or Mathematical Modelling', 'Statistics, Mathematical Biology, Econometrics, or Operations Research']
# --------------------------------------------------

# %%
from sklearn.preprocessing import LabelEncoder

encoder = LabelEncoder()

for column in df_cleaned.select_dtypes(include=['object']).columns:
    df_cleaned[column] = encoder.fit_transform(df_cleaned[column])

# %%
df_cleaned
# Out:
#      How confident are you in your understanding of Mathematics?    \
# 0                                                    0
# 1                                                    0
# 2                                                    0
# 3                                                    0
# 4                                                    3
# ..                                                 ...
# 192                                                  3
# 193                                                  2
# 194                                                  3
# 196                                                  0
# 197                                                  0
#
#      How would you rate your performance in subjects related to Mathematics (e.g., Mathematics, Physics, Computer Science)?    \
# 0                                                    0
# 1                                                    2
# 2                                                    2
# 3                                                    2
# 4                                                    0
# ..                                                 ...
# 192                                                  3
# 193                                                  0
# 194                                                  0
# 196                                                  2
# 197                                                  0
#
#      How interested are you in pursuing a career in fields that require strong mathematical skills (e.g., Engineering, Data Science, Finance, Research)?    \
# 0                                                    3
# 1                                                    4
# 2                                                    0
# 3                                                    1
# 4                                                    3
# ..                                                 ...
# 192                                                  4
# 193                                                  4
# 194                                                  3
# 196                                                  0
# 197                                                  0
#
#      How important is a career that involves Mathematics for you?    \
# 0                                                    1
# 1                                                    2
# 2                                                    2
# 3                                                    0
# 4                                                    2
# ..                                                 ...
# 192                                                  2
# 193                                                  0
# 194                                                  2
# 196                                                  2
# 197                                                  2
#
#       How do you rate your problem-solving skills in mathematical contexts?    \
# 0                                                    3
# 1                                                    2
# 2                                                    2
# 3                                                    3
# 4                                                    0
# ..                                                 ...
# 192                                                  4
# 193                                                  1
# 194                                                  0
# 196                                                  0
# 197                                                  3
#
#      Do you enjoy working on math-related projects or problems?    \
# 0                                                    1
# 1                                                    2
# 2                                                    2
# 3                                                    2
# 4                                                    0
# ..                                                 ...
# 192                                                  1
# 193                                                  1
# 194                                                  2
# 196                                                  2
# 197                                                  2
#
#      Do you prefer working in teams for solving math-related problems?    \
# 0                                                    2
# 1                                                    2
# 2                                                    0
# 3                                                    2
# 4                                                    1
# ..                                                 ...
# 192                                                  1
# 193                                                  0
# 194                                                  2
# 196                                                  2
# 197                                                  2
#
#      How comfortable are you with using technology or software (e.g., Java, Python, C, etc) for solving mathematical problems?    \
# 0                                                    3
# 1                                                    1
# 2                                                    0
# 3                                                    1
# 4                                                    3
# ..                                                 ...
# 192                                                  3
# 193                                                  1
# 194                                                  1
# 196                                                  0
# 197                                                  0
#
#      Suggested Degree
# 0                   2
# 1                   1
# 2                   1
# 3                   2
# 4                   0
# ..                ...
# 192                 2
# 193                 0
# 194                 2
# 196                 1
# 197                 1
#
# [174 rows x 9 columns]

# %%
output_data=df_cleaned["Suggested Degree"]
output_data
# Out:
# 0      2
# 1      1
# 2      1
# 3      2
# 4      0
#       ..
# 192    2
# 193    0
# 194    2
# 196    1
# 197    1
# Name: Suggested Degree, Length: 174, dtype: int32

# %%
input_data=df_cleaned.drop("Suggested Degree", axis=1)
input_data
# Out:
#      How confident are you in your understanding of Mathematics?    \
# 0                                                    0
# 1                                                    0
# 2                                                    0
# 3                                                    0
# 4                                                    3
# ..                                                 ...
# 192                                                  3
# 193                                                  2
# 194                                                  3
# 196                                                  0
# 197                                                  0
#
#      How would you rate your performance in subjects related to Mathematics (e.g., Mathematics, Physics, Computer Science)?    \
# 0                                                    0
# 1                                                    2
# 2                                                    2
# 3                                                    2
# 4                                                    0
# ..                                                 ...
# 192                                                  3
# 193                                                  0
# 194                                                  0
# 196                                                  2
# 197                                                  0
#
#      How interested are you in pursuing a career in fields that require strong mathematical skills (e.g., Engineering, Data Science, Finance, Research)?    \
# 0                                                    3
# 1                                                    4
# 2                                                    0
# 3                                                    1
# 4                                                    3
# ..                                                 ...
# 192                                                  4
# 193                                                  4
# 194                                                  3
# 196                                                  0
# 197                                                  0
#
#      How important is a career that involves Mathematics for you?    \
# 0                                                    1
# 1                                                    2
# 2                                                    2
# 3                                                    0
# 4                                                    2
# ..                                                 ...
# 192                                                  2
# 193                                                  0
# 194                                                  2
# 196                                                  2
# 197                                                  2
#
#       How do you rate your problem-solving skills in mathematical contexts?    \
# 0                                                    3
# 1                                                    2
# 2                                                    2
# 3                                                    3
# 4                                                    0
# ..                                                 ...
# 192                                                  4
# 193                                                  1
# 194                                                  0
# 196                                                  0
# 197                                                  3
#
#      Do you enjoy working on math-related projects or problems?    \
# 0                                                    1
# 1                                                    2
# 2                                                    2
# 3                                                    2
# 4                                                    0
# ..                                                 ...
# 192                                                  1
# 193                                                  1
# 194                                                  2
# 196                                                  2
# 197                                                  2
#
#      Do you prefer working in teams for solving math-related problems?    \
# 0                                                    2
# 1                                                    2
# 2                                                    0
# 3                                                    2
# 4                                                    1
# ..                                                 ...
# 192                                                  1
# 193                                                  0
# 194                                                  2
# 196                                                  2
# 197                                                  2
#
#      How comfortable are you with using technology or software (e.g., Java, Python, C, etc) for solving mathematical problems?
# 0                                                    3
# 1                                                    1
# 2                                                    0
# 3                                                    1
# 4                                                    3
# ..                                                 ...
# 192                                                  3
# 193                                                  1
# 194                                                  1
# 196                                                  0
# 197                                                  0
#
# [174 rows x 8 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,x_test,Y_train,y_test=train_test_split(input_data,output_data,test_size=0.33,random_state=42)

# %%
X_train.shape
# Out:
# (116, 8)

# %%
x_test.shape
# Out:
# (58, 8)

# %%
y_test.shape
# Out:
# (58,)

# %%
Y_train.shape
# Out:
# (116,)

# %%
from sklearn.ensemble import BaggingClassifier
from sklearn.tree import DecisionTreeClassifier

# %%
# Initialize base estimator
base_estimator = DecisionTreeClassifier()

# Define Bagging Classifier (use 'estimator' instead of 'base_estimator')
bagging_clf = BaggingClassifier(estimator=base_estimator, random_state=42)

# %%
bagging_clf.fit(X_train, Y_train)
# Out:
# BaggingClassifier(estimator=DecisionTreeClassifier(), random_state=42)

# %%
bagging_clf.score(x_test,y_test)*100
# Out:
# 81.03448275862068

# %%
bagging_clf.score(X_train,Y_train)*100
# Out:
# 96.55172413793103

# %%
y_pred = bagging_clf.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, f1_score, recall_score, precision_score
import pandas as pd

# Assuming y_test and y_pred are already defined
# y_pred is the predicted values for the test set, y_test is the actual values

print("For BaggingClassifier Model")
print("-" * 50)

# Get the number of unique classes in the target variable
n_classes = len(set(y_test))

# Confusion Matrix
cf = confusion_matrix(y_test, y_pred)

# Convert the confusion matrix to a DataFrame
cf_df = pd.DataFrame(cf, columns=[f"Class {i}" for i in range(n_classes)], index=[f"Class {i}" for i in range(n_classes)])

# Print the confusion matrix
print(cf_df)
print("-" * 50)

# Test dataset evaluation metrics
print(f"Test dataset accuracy_score: {accuracy_score(y_test, y_pred)*100:.4f}")
print(f"Test dataset f1_score: {f1_score(y_test, y_pred, average='weighted')*100:.4f}")
print(f"Test dataset recall_score: {recall_score(y_test, y_pred, average='weighted')*100:.4f}")
print(f"Test dataset precision_score: {precision_score(y_test, y_pred, average='weighted')*100:.4f}")
# Out:
# For BaggingClassifier Model
# --------------------------------------------------
#          Class 0  Class 1  Class 2
# Class 0        3        0        4
# Class 1        0        7        1
# Class 2        3        3       37
# --------------------------------------------------
# Test dataset accuracy_score: 81.0345
# Test dataset f1_score: 80.8419
# Test dataset recall_score: 81.0345
# Test dataset precision_score: 81.0016

# %%
import joblib

# %%
joblib.dump(bagging_clf,"Maths_Final_Predicator")
# Out:
# ['Maths_Final_Predicator']
